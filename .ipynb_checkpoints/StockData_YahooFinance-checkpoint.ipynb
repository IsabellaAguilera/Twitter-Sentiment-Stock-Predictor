# %% [markdown]
# # Import dependencies and libraries
#         - make sure the constituents_csv.csv ( used for ticker to sector map) is available in the same directory when you run this code.

# %%
# pip install pickle, yfinance
import bs4 as bs
import datetime as dt
import os
import pickle
import requests
import pandas as pd
import yfinance as yf
import pymongo

# %% [markdown]
# # Generate S&P 500 Ticker list

# %%
# Define function that generates the S&P 500 ticker list by scraping wikipedia
def save_sp500_tickers():
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        tickers.append(ticker)
        
    with open("sp500tickers.pickle", "wb") as f:
        pickle.dump(tickers, f)
    return tickers

# Call the save_sp500_tickers to return the list of tickers
s=save_sp500_tickers()

# Strip the '/n' from the ticker list and assign it to a list variable called ticker 
ticker=[]

for i in s:
    tr=i.strip('\n')
    ticker.append(tr)
    
# display S&P 500 ticker list
ticker
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'AGN',
#  'ADS',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ARNC',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'ATO',
#  'T',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BK',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIIB',
#  'BLK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF.B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CPRI',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
#  'CTL',
#  'CERN',
#  'CF',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'XEC',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CTXS',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'CXO',
#  'COP',
#  'ED',
#  'STZ',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'COST',
#  'COTY',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DG',
#  'DLTR',
#  'D',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DRE',
#  'DD',
#  'DXC',
#  'ETFC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'EMR',
#  'ETR',
#  'EOG',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'EVRG',
#  'ES',
#  'RE',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FB',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FIS',
#  'FITB',
#  'FE',
#  'FRC',
#  'FISV',
#  'FLT',
#  'FLIR',
#  'FLS',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FBHS',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GPS',
#  'GRMN',
#  'IT',
#  'GD',
#  'GE',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GS',
#  'GWW',
#  'HRB',
#  'HAL',
#  'HBI',
#  'HOG',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HP',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HFC',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IEX',
#  'IDXX',
#  'INFO',
#  'ITW',
#  'ILMN',
#  'IR',
#  'INTC',
#  'ICE',
#  'IBM',
#  'INCY',
#  'IP',
#  'IPG',
#  'IFF',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'IPGP',
#  'IQV',
#  'IRM',
#  'JKHY',
#  'J',
#  'JBHT',
#  'SJM',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'KSU',
#  'K',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KSS',
#  'KHC',
#  'KR',
#  'LB',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LEG',
#  'LDOS',
#  'LEN',
#  'LLY',
#  'LNC',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LYB',
#  'MTB',
#  'M',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MKC',
#  'MXIM',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MHK',
#  'TAP',
#  'MDLZ',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'MYL',
#  'NDAQ',
#  'NOV',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NLSN',
#  'NKE',
#  'NI',
#  'NBL',
#  'JWN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NLOK',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'OKE',
#  'ORCL',
#  'PCAR',
#  'PKG',
#  'PH',
#  'PAYX',
#  'PYPL',
#  'PNR',
#  'PBCT',
#  'PEP',
#  'PKI',
#  'PRGO',
#  'PFE',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PSA',
#  'PHM',
#  'PVH',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTN',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SLG',
#  'SNA',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STE',
#  'SYK',
#  'SIVB',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TGT',
#  'TEL',
#  'FTI',
#  'TFX',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TIF',
#  'TJX',
#  'TSCO',
#  'TDG',
#  'TRV',
#  'TFC',
#  'TWTR',
#  'TSN',
#  'UDR',
#  'ULTA',
#  'USB',
#  'UAA',
#  'UA',
#  'UNP',
#  'UAL',
#  'UNH',
#  'UPS',
#  'URI',
#  'UTX',
#  'UHS',
#  'UNM',
#  'VFC',
#  'VLO',
#  'VAR',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VIAC',
#  'V',
#  'VNO',
#  'VMC',
#  'WRB',
#  'WAB',
#  'WMT',
#  'WBA',
#  'DIS',
#  'WM',
#  'WAT',
#  'WEC',
#  'WCG',
#  'WFC',
#  'WELL',
#  'WDC',
#  'WU',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WLTW',
#  'WYNN',
#  'XEL',
#  'XRX',
#  'XLNX',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %% [markdown]
# # Generate Ticker to Sector map

# %%
# Read CSV file to display the symbol ->Name-> sector info
sector=pd.read_csv('constituents_csv.csv')
sector.head()
# Out:
#   Symbol                 Name                  Sector
# 0    MMM           3M Company             Industrials
# 1    AOS      A.O. Smith Corp             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV          AbbVie Inc.             Health Care
# 4    ACN        Accenture plc  Information Technology

# %%
# Create a dictionary sector_map that maps ticker to sector
sector_map = dict(zip(sector.Symbol,sector.Sector))
sector_map
# Out:
# {'MMM': 'Industrials',
#  'AOS': 'Industrials',
#  'ABT': 'Health Care',
#  'ABBV': 'Health Care',
#  'ACN': 'Information Technology',
#  'ATVI': 'Information Technology',
#  'AYI': 'Industrials',
#  'ADBE': 'Information Technology',
#  'AAP': 'Consumer Discretionary',
#  'AMD': 'Information Technology',
#  'AES': 'Utilities',
#  'AET': 'Health Care',
#  'AMG': 'Financials',
#  'AFL': 'Financials',
#  'A': 'Health Care',
#  'APD': 'Materials',
#  'AKAM': 'Information Technology',
#  'ALK': 'Industrials',
#  'ALB': 'Materials',
#  'ARE': 'Real Estate',
#  'ALXN': 'Health Care',
#  'ALGN': 'Health Care',
#  'ALLE': 'Industrials',
#  'AGN': 'Health Care',
#  'ADS': 'Information Technology',
#  'LNT': 'Utilities',
#  'ALL': 'Financials',
#  'GOOGL': 'Information Technology',
#  'GOOG': 'Information Technology',
#  'MO': 'Consumer Staples',
#  'AMZN': 'Consumer Discretionary',
#  'AEE': 'Utilities',
#  'AAL': 'Industrials',
#  'AEP': 'Utilities',
#  'AXP': 'Financials',
#  'AIG': 'Financials',
#  'AMT': 'Real Estate',
#  'AWK': 'Utilities',
#  'AMP': 'Financials',
#  'ABC': 'Health Care',
#  'AME': 'Industrials',
#  'AMGN': 'Health Care',
#  'APH': 'Information Technology',
#  'APC': 'Energy',
#  'ADI': 'Information Technology',
#  'ANDV': 'Energy',
#  'ANSS': 'Information Technology',
#  'ANTM': 'Health Care',
#  'AON': 'Financials',
#  'APA': 'Energy',
#  'AIV': 'Real Estate',
#  'AAPL': 'Information Technology',
#  'AMAT': 'Information Technology',
#  'APTV': 'Consumer Discretionary',
#  'ADM': 'Consumer Staples',
#  'ARNC': 'Industrials',
#  'AJG': 'Financials',
#  'AIZ': 'Financials',
#  'T': 'Telecommunication Services',
#  'ADSK': 'Information Technology',
#  'ADP': 'Information Technology',
#  'AZO': 'Consumer Discretionary',
#  'AVB': 'Real Estate',
#  'AVY': 'Materials',
#  'BHGE': 'Energy',
#  'BLL': 'Materials',
#  'BAC': 'Financials',
#  'BAX': 'Health Care',
#  'BBT': 'Financials',
#  'BDX': 'Health Care',
#  'BRK.B': 'Financials',
#  'BBY': 'Consumer Discretionary',
#  'BIIB': 'Health Care',
#  'BLK': 'Financials',
#  'HRB': 'Financials',
#  'BA': 'Industrials',
#  'BKNG': 'Consumer Discretionary',
#  'BWA': 'Consumer Discretionary',
#  'BXP': 'Real Estate',
#  'BSX': 'Health Care',
#  'BHF': 'Financials',
#  'BMY': 'Health Care',
#  'AVGO': 'Information Technology',
#  'BF.B': 'Consumer Staples',
#  'CHRW': 'Industrials',
#  'CA': 'Information Technology',
#  'COG': 'Energy',
#  'CDNS': 'Information Technology',
#  'CPB': 'Consumer Staples',
#  'COF': 'Financials',
#  'CAH': 'Health Care',
#  'KMX': 'Consumer Discretionary',
#  'CCL': 'Consumer Discretionary',
#  'CAT': 'Industrials',
#  'CBOE': 'Financials',
#  'CBRE': 'Real Estate',
#  'CBS': 'Consumer Discretionary',
#  'CELG': 'Health Care',
#  'CNC': 'Health Care',
#  'CNP': 'Utilities',
#  'CTL': 'Telecommunication Services',
#  'CERN': 'Health Care',
#  'CF': 'Materials',
#  'SCHW': 'Financials',
#  'CHTR': 'Consumer Discretionary',
#  'CVX': 'Energy',
#  'CMG': 'Consumer Discretionary',
#  'CB': 'Financials',
#  'CHD': 'Consumer Staples',
#  'CI': 'Health Care',
#  'XEC': 'Energy',
#  'CINF': 'Financials',
#  'CTAS': 'Industrials',
#  'CSCO': 'Information Technology',
#  'C': 'Financials',
#  'CFG': 'Financials',
#  'CTXS': 'Information Technology',
#  'CME': 'Financials',
#  'CMS': 'Utilities',
#  'KO': 'Consumer Staples',
#  'CTSH': 'Information Technology',
#  'CL': 'Consumer Staples',
#  'CMCSA': 'Consumer Discretionary',
#  'CMA': 'Financials',
#  'CAG': 'Consumer Staples',
#  'CXO': 'Energy',
#  'COP': 'Energy',
#  'ED': 'Utilities',
#  'STZ': 'Consumer Staples',
#  'GLW': 'Information Technology',
#  'COST': 'Consumer Staples',
#  'COTY': 'Consumer Staples',
#  'CCI': 'Real Estate',
#  'CSRA': 'Information Technology',
#  'CSX': 'Industrials',
#  'CMI': 'Industrials',
#  'CVS': 'Consumer Staples',
#  'DHI': 'Consumer Discretionary',
#  'DHR': 'Health Care',
#  'DRI': 'Consumer Discretionary',
#  'DVA': 'Health Care',
#  'DE': 'Industrials',
#  'DAL': 'Industrials',
#  'XRAY': 'Health Care',
#  'DVN': 'Energy',
#  'DLR': 'Real Estate',
#  'DFS': 'Financials',
#  'DISCA': 'Consumer Discretionary',
#  'DISCK': 'Consumer Discretionary',
#  'DISH': 'Consumer Discretionary',
#  'DG': 'Consumer Discretionary',
#  'DLTR': 'Consumer Discretionary',
#  'D': 'Utilities',
#  'DOV': 'Industrials',
#  'DWDP': 'Materials',
#  'DPS': 'Consumer Staples',
#  'DTE': 'Utilities',
#  'DUK': 'Utilities',
#  'DRE': 'Real Estate',
#  'DXC': 'Information Technology',
#  'ETFC': 'Financials',
#  'EMN': 'Materials',
#  'ETN': 'Industrials',
#  'EBAY': 'Information Technology',
#  'ECL': 'Materials',
#  'EIX': 'Utilities',
#  'EW': 'Health Care',
#  'EA': 'Information Technology',
#  'EMR': 'Industrials',
#  'ETR': 'Utilities',
#  'EVHC': 'Health Care',
#  'EOG': 'Energy',
#  'EQT': 'Energy',
#  'EFX': 'Industrials',
#  'EQIX': 'Real Estate',
#  'EQR': 'Real Estate',
#  'ESS': 'Real Estate',
#  'EL': 'Consumer Staples',
#  'RE': 'Financials',
#  'ES': 'Utilities',
#  'EXC': 'Utilities',
#  'EXPE': 'Consumer Discretionary',
#  'EXPD': 'Industrials',
#  'ESRX': 'Health Care',
#  'EXR': 'Real Estate',
#  'XOM': 'Energy',
#  'FFIV': 'Information Technology',
#  'FB': 'Information Technology',
#  'FAST': 'Industrials',
#  'FRT': 'Real Estate',
#  'FDX': 'Industrials',
#  'FIS': 'Information Technology',
#  'FITB': 'Financials',
#  'FE': 'Utilities',
#  'FISV': 'Information Technology',
#  'FLIR': 'Information Technology',
#  'FLS': 'Industrials',
#  'FLR': 'Industrials',
#  'FMC': 'Materials',
#  'FL': 'Consumer Discretionary',
#  'F': 'Consumer Discretionary',
#  'FTV': 'Industrials',
#  'FBHS': 'Industrials',
#  'BEN': 'Financials',
#  'FCX': 'Materials',
#  'GPS': 'Consumer Discretionary',
#  'GRMN': 'Consumer Discretionary',
#  'IT': 'Information Technology',
#  'GD': 'Industrials',
#  'GE': 'Industrials',
#  'GGP': 'Real Estate',
#  'GIS': 'Consumer Staples',
#  'GM': 'Consumer Discretionary',
#  'GPC': 'Consumer Discretionary',
#  'GILD': 'Health Care',
#  'GPN': 'Information Technology',
#  'GS': 'Financials',
#  'GT': 'Consumer Discretionary',
#  'GWW': 'Industrials',
#  'HAL': 'Energy',
#  'HBI': 'Consumer Discretionary',
#  'HOG': 'Consumer Discretionary',
#  'HRS': 'Information Technology',
#  'HIG': 'Financials',
#  'HAS': 'Consumer Discretionary',
#  'HCA': 'Health Care',
#  'HCP': 'Real Estate',
#  'HP': 'Energy',
#  'HSIC': 'Health Care',
#  'HES': 'Energy',
#  'HPE': 'Information Technology',
#  'HLT': 'Consumer Discretionary',
#  'HOLX': 'Health Care',
#  'HD': 'Consumer Discretionary',
#  'HON': 'Industrials',
#  'HRL': 'Consumer Staples',
#  'HST': 'Real Estate',
#  'HPQ': 'Information Technology',
#  'HUM': 'Health Care',
#  'HBAN': 'Financials',
#  'HII': 'Industrials',
#  'IDXX': 'Health Care',
#  'INFO': 'Industrials',
#  'ITW': 'Industrials',
#  'ILMN': 'Health Care',
#  'INCY': 'Health Care',
#  'IR': 'Industrials',
#  'INTC': 'Information Technology',
#  'ICE': 'Financials',
#  'IBM': 'Information Technology',
#  'IP': 'Materials',
#  'IPG': 'Consumer Discretionary',
#  'IFF': 'Materials',
#  'INTU': 'Information Technology',
#  'ISRG': 'Health Care',
#  'IVZ': 'Financials',
#  'IPGP': 'Information Technology',
#  'IQV': 'Health Care',
#  'IRM': 'Real Estate',
#  'JBHT': 'Industrials',
#  'JEC': 'Industrials',
#  'SJM': 'Consumer Staples',
#  'JNJ': 'Health Care',
#  'JCI': 'Industrials',
#  'JPM': 'Financials',
#  'JNPR': 'Information Technology',
#  'KSU': 'Industrials',
#  'K': 'Consumer Staples',
#  'KEY': 'Financials',
#  'KMB': 'Consumer Staples',
#  'KIM': 'Real Estate',
#  'KMI': 'Energy',
#  'KLAC': 'Information Technology',
#  'KSS': 'Consumer Discretionary',
#  'KHC': 'Consumer Staples',
#  'KR': 'Consumer Staples',
#  'LB': 'Consumer Discretionary',
#  'LLL': 'Industrials',
#  'LH': 'Health Care',
#  'LRCX': 'Information Technology',
#  'LEG': 'Consumer Discretionary',
#  'LEN': 'Consumer Discretionary',
#  'LUK': 'Financials',
#  'LLY': 'Health Care',
#  'LNC': 'Financials',
#  'LKQ': 'Consumer Discretionary',
#  'LMT': 'Industrials',
#  'L': 'Financials',
#  'LOW': 'Consumer Discretionary',
#  'LYB': 'Materials',
#  'MTB': 'Financials',
#  'MAC': 'Real Estate',
#  'M': 'Consumer Discretionary',
#  'MRO': 'Energy',
#  'MPC': 'Energy',
#  'MAR': 'Consumer Discretionary',
#  'MMC': 'Financials',
#  'MLM': 'Materials',
#  'MAS': 'Industrials',
#  'MA': 'Information Technology',
#  'MAT': 'Consumer Discretionary',
#  'MKC': 'Consumer Staples',
#  'MCD': 'Consumer Discretionary',
#  'MCK': 'Health Care',
#  'MDT': 'Health Care',
#  'MRK': 'Health Care',
#  'MET': 'Financials',
#  'MTD': 'Health Care',
#  'MGM': 'Consumer Discretionary',
#  'KORS': 'Consumer Discretionary',
#  'MCHP': 'Information Technology',
#  'MU': 'Information Technology',
#  'MSFT': 'Information Technology',
#  'MAA': 'Real Estate',
#  'MHK': 'Consumer Discretionary',
#  'TAP': 'Consumer Staples',
#  'MDLZ': 'Consumer Staples',
#  'MON': 'Materials',
#  'MNST': 'Consumer Staples',
#  'MCO': 'Financials',
#  'MS': 'Financials',
#  'MSI': 'Information Technology',
#  'MYL': 'Health Care',
#  'NDAQ': 'Financials',
#  'NOV': 'Energy',
#  'NAVI': 'Financials',
#  'NKTR': 'Health Care',
#  'NTAP': 'Information Technology',
#  'NFLX': 'Information Technology',
#  'NWL': 'Consumer Discretionary',
#  'NFX': 'Energy',
#  'NEM': 'Materials',
#  'NWSA': 'Consumer Discretionary',
#  'NWS': 'Consumer Discretionary',
#  'NEE': 'Utilities',
#  'NLSN': 'Industrials',
#  'NKE': 'Consumer Discretionary',
#  'NI': 'Utilities',
#  'NBL': 'Energy',
#  'JWN': 'Consumer Discretionary',
#  'NSC': 'Industrials',
#  'NTRS': 'Financials',
#  'NOC': 'Industrials',
#  'NCLH': 'Consumer Discretionary',
#  'NRG': 'Utilities',
#  'NUE': 'Materials',
#  'NVDA': 'Information Technology',
#  'ORLY': 'Consumer Discretionary',
#  'OXY': 'Energy',
#  'OMC': 'Consumer Discretionary',
#  'OKE': 'Energy',
#  'ORCL': 'Information Technology',
#  'PCAR': 'Industrials',
#  'PKG': 'Materials',
#  'PH': 'Industrials',
#  'PAYX': 'Information Technology',
#  'PYPL': 'Information Technology',
#  'PNR': 'Industrials',
#  'PBCT': 'Financials',
#  'PEP': 'Consumer Staples',
#  'PKI': 'Health Care',
#  'PRGO': 'Health Care',
#  'PFE': 'Health Care',
#  'PCG': 'Utilities',
#  'PM': 'Consumer Staples',
#  'PSX': 'Energy',
#  'PNW': 'Utilities',
#  'PXD': 'Energy',
#  'PNC': 'Financials',
#  'RL': 'Consumer Discretionary',
#  'PPG': 'Materials',
#  'PPL': 'Utilities',
#  'PX': 'Materials',
#  'PFG': 'Financials',
#  'PG': 'Consumer Staples',
#  'PGR': 'Financials',
#  'PLD': 'Real Estate',
#  'PRU': 'Financials',
#  'PEG': 'Utilities',
#  'PSA': 'Real Estate',
#  'PHM': 'Consumer Discretionary',
#  'PVH': 'Consumer Discretionary',
#  'QRVO': 'Information Technology',
#  'QCOM': 'Information Technology',
#  'PWR': 'Industrials',
#  'DGX': 'Health Care',
#  'RRC': 'Energy',
#  'RJF': 'Financials',
#  'RTN': 'Industrials',
#  'O': 'Real Estate',
#  'RHT': 'Information Technology',
#  'REG': 'Real Estate',
#  'REGN': 'Health Care',
#  'RF': 'Financials',
#  'RSG': 'Industrials',
#  'RMD': 'Health Care',
#  'RHI': 'Industrials',
#  'ROK': 'Industrials',
#  'COL': 'Industrials',
#  'ROP': 'Industrials',
#  'ROST': 'Consumer Discretionary',
#  'RCL': 'Consumer Discretionary',
#  'SPGI': 'Financials',
#  'CRM': 'Information Technology',
#  'SBAC': 'Real Estate',
#  'SCG': 'Utilities',
#  'SLB': 'Energy',
#  'STX': 'Information Technology',
#  'SEE': 'Materials',
#  'SRE': 'Utilities',
#  'SHW': 'Materials',
#  'SPG': 'Real Estate',
#  'SWKS': 'Information Technology',
#  'SLG': 'Real Estate',
#  'SNA': 'Consumer Discretionary',
#  'SO': 'Utilities',
#  'LUV': 'Industrials',
#  'SWK': 'Consumer Discretionary',
#  'SBUX': 'Consumer Discretionary',
#  'STT': 'Financials',
#  'SRCL': 'Industrials',
#  'SYK': 'Health Care',
#  'STI': 'Financials',
#  'SIVB': 'Financials',
#  'SYMC': 'Information Technology',
#  'SYF': 'Financials',
#  'SNPS': 'Information Technology',
#  'SYY': 'Consumer Staples',
#  'TROW': 'Financials',
#  'TTWO': 'Information Technology',
#  'TPR': 'Consumer Discretionary',
#  'TGT': 'Consumer Discretionary',
#  'TEL': 'Information Technology',
#  'FTI': 'Energy',
#  'TXN': 'Information Technology',
#  'TXT': 'Industrials',
#  'BK': 'Financials',
#  'CLX': 'Consumer Staples',
#  'COO': 'Health Care',
#  'HSY': 'Consumer Staples',
#  'MOS': 'Materials',
#  'TRV': 'Financials',
#  'DIS': 'Consumer Discretionary',
#  'TMO': 'Health Care',
#  'TIF': 'Consumer Discretionary',
#  'TWX': 'Consumer Discretionary',
#  'TJX': 'Consumer Discretionary',
#  'TMK': 'Financials',
#  'TSS': 'Information Technology',
#  'TSCO': 'Consumer Discretionary',
#  'TDG': 'Industrials',
#  'TRIP': 'Consumer Discretionary',
#  'FOXA': 'Consumer Discretionary',
#  'FOX': 'Consumer Discretionary',
#  'TSN': 'Consumer Staples',
#  'USB': 'Financials',
#  'UDR': 'Real Estate',
#  'ULTA': 'Consumer Discretionary',
#  'UAA': 'Consumer Discretionary',
#  'UA': 'Consumer Discretionary',
#  'UNP': 'Industrials',
#  'UAL': 'Industrials',
#  'UNH': 'Health Care',
#  'UPS': 'Industrials',
#  'URI': 'Industrials',
#  'UTX': 'Industrials',
#  'UHS': 'Health Care',
#  'UNM': 'Financials',
#  'VFC': 'Consumer Discretionary',
#  'VLO': 'Energy',
#  'VAR': 'Health Care',
#  'VTR': 'Real Estate',
#  'VRSN': 'Information Technology',
#  'VRSK': 'Industrials',
#  'VZ': 'Telecommunication Services',
#  'VRTX': 'Health Care',
#  'VIAB': 'Consumer Discretionary',
#  'V': 'Information Technology',
#  'VNO': 'Real Estate',
#  'VMC': 'Materials',
#  'WMT': 'Consumer Staples',
#  'WBA': 'Consumer Staples',
#  'WM': 'Industrials',
#  'WAT': 'Health Care',
#  'WEC': 'Utilities',
#  'WFC': 'Financials',
#  'WELL': 'Real Estate',
#  'WDC': 'Information Technology',
#  'WU': 'Information Technology',
#  'WRK': 'Materials',
#  'WY': 'Real Estate',
#  'WHR': 'Consumer Discretionary',
#  'WMB': 'Energy',
#  'WLTW': 'Financials',
#  'WYN': 'Consumer Discretionary',
#  'WYNN': 'Consumer Discretionary',
#  'XEL': 'Utilities',
#  'XRX': 'Information Technology',
#  'XLNX': 'Information Technology',
#  'XL': 'Financials',
#  'XYL': 'Industrials',
#  'YUM': 'Consumer Discretionary',
#  'ZBH': 'Health Care',
#  'ZION': 'Financials',
#  'ZTS': 'Health Care'}

# %% [markdown]
# #  S&P 500 data - Download historical market data ( 1mo) from Yahoo! Finance

# %%
# initialize variables and counter
df_ = []
count=0

# loop through ticker list and pull historic market data from yahoo Finance
for ticker in ticker:
    stock = yf.Ticker(ticker)
    stock_data=stock.history(period="1mo",actions=False,auto_adjust=False)
    # map  ticker symbol to sector and add as columns to dataframe
    stock_data['Symbol']=ticker
    stock_data['Sector']=stock_data['Symbol'].map(sector_map)
    df_.append(stock_data)
    
    #continue appending dataframe to a list (df_) and pop off the last dataframe. df_[0] is now the ultimate dataframe with al stockdata.
    if (len(df_)>1):
        df_[0] = df_[0].append(df_[-1])
        df_.pop(-1)

# rename the dataframe. final_data is the ultimate dataframe with stockdata for S&P 500 for 1 month period
final_data=df_[0]
final_data
# Out:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: No data found for this date range, symbol may be delisted
#               Open    High     Low   Close  Adj Close     Volume Symbol  \
# Date
# 2019-12-16  168.94  170.83  168.19  170.75     170.75  2917200.0    MMM
# 2019-12-17  170.35  171.79  169.21  169.93     169.93  2672600.0    MMM
# 2019-12-18  169.78  170.00  168.19  169.03     169.03  2270400.0    MMM
# 2019-12-19  169.62  172.58  169.15  172.15     172.15  2757600.0    MMM
# 2019-12-20  174.79  175.47  172.20  175.37     175.37  7513000.0    MMM
# ...            ...     ...     ...     ...        ...        ...    ...
# 2020-01-07  133.00  134.81  132.67  133.58     133.58  1224500.0    ZTS
# 2020-01-08  133.76  135.27  133.24  133.29     133.29  1766700.0    ZTS
# 2020-01-09  134.01  136.37  134.01  135.06     135.06  2075400.0    ZTS
# 2020-01-10  135.30  136.00  134.77  135.57     135.57  1249000.0    ZTS
# 2020-01-13  136.07  136.75  135.46  136.51     136.51  1767197.0    ZTS
#
#                  Sector
# Date
# 2019-12-16  Industrials
# 2019-12-17  Industrials
# 2019-12-18  Industrials
# 2019-12-19  Industrials
# 2019-12-20  Industrials
# ...                 ...
# 2020-01-07  Health Care
# 2020-01-08  Health Care
# 2020-01-09  Health Care
# 2020-01-10  Health Care
# 2020-01-13  Health Care
#
# [9572 rows x 8 columns]

# %%
# sort data by descending order on date, and sort on Symbol and Sector
market_data=final_data.reset_index()
market_data.sort_values(by=['Date'], ascending=False,inplace=True)
market_data.sort_values(by=['Sector','Symbol',],na_position='first',inplace=True)

# Drop NaN values , 50 companies do not have an assoicated sector indentified and will be dropped
market_Data=market_data.dropna()
market_Data.reset_index(drop=True,inplace=True)
market_Data=market_Data.reset_index()
market_Data
# Out:
#       index       Date    Open    High     Low   Close  Adj Close     Volume  \
# 0         0 2020-01-13  145.33  147.00  142.76  145.26     145.26  2032515.0
# 1         1 2020-01-10  153.18  153.50  148.61  149.01     149.01  1416100.0
# 2         2 2020-01-09  153.78  153.98  150.25  152.87     152.87  1177400.0
# 3         3 2020-01-08  154.85  156.05  153.14  153.16     153.16   825700.0
# 4         4 2020-01-07  156.90  157.40  152.41  154.94     154.94  1129500.0
# ...     ...        ...     ...     ...     ...     ...        ...        ...
# 8621   8621 2019-12-20   64.07   64.67   63.74   64.15      63.74  7834500.0
# 8622   8622 2019-12-19   64.00   64.01   63.57   63.85      63.44  2544800.0
# 8623   8623 2019-12-18   63.57   63.92   63.24   63.79      63.38  3404000.0
# 8624   8624 2019-12-17   63.22   63.86   63.02   63.46      63.05  2788800.0
# 8625   8625 2019-12-16   62.18   63.06   62.07   63.03      62.62  2845300.0
#
#      Symbol                  Sector
# 0       AAP  Consumer Discretionary
# 1       AAP  Consumer Discretionary
# 2       AAP  Consumer Discretionary
# 3       AAP  Consumer Discretionary
# 4       AAP  Consumer Discretionary
# ...     ...                     ...
# 8621    XEL               Utilities
# 8622    XEL               Utilities
# 8623    XEL               Utilities
# 8624    XEL               Utilities
# 8625    XEL               Utilities
#
# [8626 rows x 10 columns]

# %% [markdown]
# # Connect to MongoDB and store data

# %%
# modify the dataframe and convert to dict to store in mongoDB
market_Data = market_Data.rename(columns={'index':'_id'})

# Add 1 to each "_id" because first activity must start with 1 not 0.  Starting with "_id" = 0 will throw an error
market_Data['_id'] = market_Data['_id'] + 1 

# convert df to dict
market_data = market_Data.to_dict('records')
market_data
# Out:
# [{'_id': 1,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 145.33,
#   'High': 147.0,
#   'Low': 142.76,
#   'Close': 145.26,
#   'Adj Close': 145.26,
#   'Volume': 2032515.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 2,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 153.18,
#   'High': 153.5,
#   'Low': 148.61,
#   'Close': 149.01,
#   'Adj Close': 149.01,
#   'Volume': 1416100.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 3,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 153.78,
#   'High': 153.98,
#   'Low': 150.25,
#   'Close': 152.87,
#   'Adj Close': 152.87,
#   'Volume': 1177400.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 4,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 154.85,
#   'High': 156.05,
#   'Low': 153.14,
#   'Close': 153.16,
#   'Adj Close': 153.16,
#   'Volume': 825700.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 5,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 156.9,
#   'High': 157.4,
#   'Low': 152.41,
#   'Close': 154.94,
#   'Adj Close': 154.94,
#   'Volume': 1129500.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 6,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 157.74,
#   'High': 158.89,
#   'Low': 156.43,
#   'Close': 156.8,
#   'Adj Close': 156.8,
#   'Volume': 880200.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 7,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 158.03,
#   'High': 159.63,
#   'Low': 157.25,
#   'Close': 159.42,
#   'Adj Close': 159.42,
#   'Volume': 567000.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 8,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 160.47,
#   'High': 160.95,
#   'Low': 157.53,
#   'Close': 159.41,
#   'Adj Close': 159.41,
#   'Volume': 944900.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 9,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 159.16,
#   'High': 160.31,
#   'Low': 158.5,
#   'Close': 160.16,
#   'Adj Close': 160.16,
#   'Volume': 609600.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 10,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 158.35,
#   'High': 160.26,
#   'Low': 157.43,
#   'Close': 159.12,
#   'Adj Close': 159.12,
#   'Volume': 563400.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 11,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 159.47,
#   'High': 159.75,
#   'Low': 158.0,
#   'Close': 158.35,
#   'Adj Close': 158.35,
#   'Volume': 487200.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 12,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 160.53,
#   'High': 161.07,
#   'Low': 158.44,
#   'Close': 159.27,
#   'Adj Close': 159.27,
#   'Volume': 482300.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 13,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 160.12,
#   'High': 162.06,
#   'Low': 159.83,
#   'Close': 160.57,
#   'Adj Close': 160.57,
#   'Volume': 324200.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 14,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 158.22,
#   'High': 160.2,
#   'Low': 156.9,
#   'Close': 159.97,
#   'Adj Close': 159.97,
#   'Volume': 683600.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 15,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 157.77,
#   'High': 158.7,
#   'Low': 156.09,
#   'Close': 158.12,
#   'Adj Close': 158.12,
#   'Volume': 1269200.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 16,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 157.47,
#   'High': 158.45,
#   'Low': 156.23,
#   'Close': 156.48,
#   'Adj Close': 156.48,
#   'Volume': 734700.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 17,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 158.13,
#   'High': 158.8,
#   'Low': 156.51,
#   'Close': 158.03,
#   'Adj Close': 157.97,
#   'Volume': 564900.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 18,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 154.51,
#   'High': 158.86,
#   'Low': 153.67,
#   'Close': 157.98,
#   'Adj Close': 157.92,
#   'Volume': 941700.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 19,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 155.47,
#   'High': 155.62,
#   'Low': 153.4,
#   'Close': 153.5,
#   'Adj Close': 153.44,
#   'Volume': 659200.0,
#   'Symbol': 'AAP',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 20,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 1891.31,
#   'High': 1898.0,
#   'Low': 1880.8,
#   'Close': 1891.3,
#   'Adj Close': 1891.3,
#   'Volume': 2504126.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 21,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 1905.37,
#   'High': 1906.94,
#   'Low': 1880.0,
#   'Close': 1883.16,
#   'Adj Close': 1883.16,
#   'Volume': 2853700.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 22,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 1909.89,
#   'High': 1917.82,
#   'Low': 1895.8,
#   'Close': 1901.05,
#   'Adj Close': 1901.05,
#   'Volume': 3167300.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 23,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 1898.04,
#   'High': 1911.0,
#   'Low': 1886.44,
#   'Close': 1891.97,
#   'Adj Close': 1891.97,
#   'Volume': 3508000.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 24,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 1904.5,
#   'High': 1913.89,
#   'Low': 1892.04,
#   'Close': 1906.86,
#   'Adj Close': 1906.86,
#   'Volume': 4044900.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 25,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 1860.0,
#   'High': 1903.69,
#   'Low': 1860.0,
#   'Close': 1902.88,
#   'Adj Close': 1902.88,
#   'Volume': 4061800.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 26,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 1864.5,
#   'High': 1886.2,
#   'Low': 1864.5,
#   'Close': 1874.97,
#   'Adj Close': 1874.97,
#   'Volume': 3764400.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 27,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 1875.0,
#   'High': 1898.01,
#   'Low': 1864.15,
#   'Close': 1898.01,
#   'Adj Close': 1898.01,
#   'Volume': 4029000.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 28,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 1842.0,
#   'High': 1853.26,
#   'Low': 1832.23,
#   'Close': 1847.84,
#   'Adj Close': 1847.84,
#   'Volume': 2506500.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 29,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 1874.0,
#   'High': 1884.0,
#   'Low': 1840.62,
#   'Close': 1846.89,
#   'Adj Close': 1846.89,
#   'Volume': 3674700.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 30,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 1882.92,
#   'High': 1901.4,
#   'Low': 1866.01,
#   'Close': 1869.8,
#   'Adj Close': 1869.8,
#   'Volume': 6186600.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 31,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 1801.01,
#   'High': 1870.46,
#   'Low': 1799.5,
#   'Close': 1868.77,
#   'Adj Close': 1868.77,
#   'Volume': 6005400.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 32,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 1793.81,
#   'High': 1795.57,
#   'Low': 1787.58,
#   'Close': 1789.21,
#   'Adj Close': 1789.21,
#   'Volume': 881300.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 33,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 1788.26,
#   'High': 1793.0,
#   'Low': 1784.51,
#   'Close': 1793.0,
#   'Adj Close': 1793.0,
#   'Volume': 2136400.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 34,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 1799.62,
#   'High': 1802.97,
#   'Low': 1782.45,
#   'Close': 1786.5,
#   'Adj Close': 1786.5,
#   'Volume': 5150800.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 35,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 1780.5,
#   'High': 1792.99,
#   'Low': 1774.06,
#   'Close': 1792.28,
#   'Adj Close': 1792.28,
#   'Volume': 2652800.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 36,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 1795.02,
#   'High': 1798.2,
#   'Low': 1782.36,
#   'Close': 1784.03,
#   'Adj Close': 1784.03,
#   'Volume': 3351400.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 37,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 1778.01,
#   'High': 1792.0,
#   'Low': 1777.39,
#   'Close': 1790.66,
#   'Adj Close': 1790.66,
#   'Volume': 3644400.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 38,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 1767.0,
#   'High': 1769.5,
#   'Low': 1757.05,
#   'Close': 1769.21,
#   'Adj Close': 1769.21,
#   'Volume': 3145200.0,
#   'Symbol': 'AMZN',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 39,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 89.42,
#   'High': 89.42,
#   'Low': 88.63,
#   'Close': 88.87,
#   'Adj Close': 88.87,
#   'Volume': 2010540.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 40,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 91.73,
#   'High': 91.73,
#   'Low': 89.39,
#   'Close': 89.51,
#   'Adj Close': 89.51,
#   'Volume': 1323600.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 41,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 94.11,
#   'High': 94.35,
#   'Low': 91.69,
#   'Close': 91.73,
#   'Adj Close': 91.73,
#   'Volume': 1087900.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 42,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 91.43,
#   'High': 93.47,
#   'Low': 90.96,
#   'Close': 93.09,
#   'Adj Close': 93.09,
#   'Volume': 2295700.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 43,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 92.33,
#   'High': 92.5,
#   'Low': 90.85,
#   'Close': 91.19,
#   'Adj Close': 91.19,
#   'Volume': 2100900.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 44,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 93.18,
#   'High': 93.18,
#   'Low': 91.74,
#   'Close': 92.35,
#   'Adj Close': 92.35,
#   'Volume': 1574900.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 45,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 94.25,
#   'High': 94.83,
#   'Low': 93.6,
#   'Close': 94.1,
#   'Adj Close': 94.1,
#   'Volume': 960600.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 46,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 95.94,
#   'High': 96.34,
#   'Low': 95.01,
#   'Close': 96.31,
#   'Adj Close': 96.31,
#   'Volume': 1655300.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 47,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 95.27,
#   'High': 95.88,
#   'Low': 94.7,
#   'Close': 94.97,
#   'Adj Close': 94.97,
#   'Volume': 673300.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 48,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 96.28,
#   'High': 96.28,
#   'Low': 95.1,
#   'Close': 95.25,
#   'Adj Close': 95.25,
#   'Volume': 613600.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 49,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 96.17,
#   'High': 96.58,
#   'Low': 95.76,
#   'Close': 96.31,
#   'Adj Close': 96.31,
#   'Volume': 757600.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 50,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 95.36,
#   'High': 95.76,
#   'Low': 94.86,
#   'Close': 95.72,
#   'Adj Close': 95.72,
#   'Volume': 519700.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 51,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 95.8,
#   'High': 96.04,
#   'Low': 94.89,
#   'Close': 94.89,
#   'Adj Close': 94.89,
#   'Volume': 320300.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 52,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 96.72,
#   'High': 96.91,
#   'Low': 95.27,
#   'Close': 95.53,
#   'Adj Close': 95.53,
#   'Volume': 1051000.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 53,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 98.93,
#   'High': 99.04,
#   'Low': 96.25,
#   'Close': 96.35,
#   'Adj Close': 96.35,
#   'Volume': 2021300.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 54,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 97.74,
#   'High': 98.3,
#   'Low': 97.1,
#   'Close': 97.85,
#   'Adj Close': 97.85,
#   'Volume': 1053500.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 55,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 96.3,
#   'High': 98.18,
#   'Low': 95.94,
#   'Close': 97.86,
#   'Adj Close': 97.86,
#   'Volume': 1285500.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 56,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 95.23,
#   'High': 95.88,
#   'Low': 94.56,
#   'Close': 95.84,
#   'Adj Close': 95.84,
#   'Volume': 1320700.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 57,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 94.84,
#   'High': 95.87,
#   'Low': 94.38,
#   'Close': 94.96,
#   'Adj Close': 94.96,
#   'Volume': 1398100.0,
#   'Symbol': 'APTV',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 58,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 1128.98,
#   'High': 1134.04,
#   'Low': 1118.79,
#   'Close': 1128.37,
#   'Adj Close': 1128.37,
#   'Volume': 210981.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 59,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 1151.0,
#   'High': 1151.0,
#   'Low': 1130.54,
#   'Close': 1132.22,
#   'Adj Close': 1132.22,
#   'Volume': 208100.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 60,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 1152.07,
#   'High': 1154.11,
#   'Low': 1144.15,
#   'Close': 1145.39,
#   'Adj Close': 1145.39,
#   'Volume': 206000.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 61,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 1141.63,
#   'High': 1157.42,
#   'Low': 1137.35,
#   'Close': 1147.49,
#   'Adj Close': 1147.49,
#   'Volume': 207900.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 62,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 1160.67,
#   'High': 1168.13,
#   'Low': 1141.39,
#   'Close': 1145.38,
#   'Adj Close': 1145.38,
#   'Volume': 269100.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 63,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 1167.01,
#   'High': 1177.74,
#   'Low': 1147.14,
#   'Close': 1165.71,
#   'Adj Close': 1165.71,
#   'Volume': 296800.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 64,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 1175.74,
#   'High': 1190.31,
#   'Low': 1175.74,
#   'Close': 1187.98,
#   'Adj Close': 1187.98,
#   'Volume': 188800.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 65,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 1194.86,
#   'High': 1197.58,
#   'Low': 1179.61,
#   'Close': 1189.74,
#   'Adj Close': 1189.74,
#   'Volume': 212200.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 66,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 1184.22,
#   'High': 1193.49,
#   'Low': 1182.77,
#   'Close': 1191.31,
#   'Adj Close': 1191.31,
#   'Volume': 191500.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 67,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 1205.83,
#   'High': 1205.83,
#   'Low': 1179.51,
#   'Close': 1183.25,
#   'Adj Close': 1183.25,
#   'Volume': 202500.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 68,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 1211.97,
#   'High': 1213.33,
#   'Low': 1200.23,
#   'Close': 1202.59,
#   'Adj Close': 1202.59,
#   'Volume': 140600.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 69,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 1217.26,
#   'High': 1220.38,
#   'Low': 1209.44,
#   'Close': 1210.72,
#   'Adj Close': 1210.72,
#   'Volume': 147000.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 70,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 1213.4,
#   'High': 1224.09,
#   'Low': 1213.4,
#   'Close': 1219.31,
#   'Adj Close': 1219.31,
#   'Volume': 77200.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 71,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 1225.42,
#   'High': 1226.74,
#   'Low': 1213.85,
#   'Close': 1213.87,
#   'Adj Close': 1213.87,
#   'Volume': 178500.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 72,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 1228.48,
#   'High': 1228.48,
#   'Low': 1219.28,
#   'Close': 1226.74,
#   'Adj Close': 1226.74,
#   'Volume': 360500.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 73,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 1222.16,
#   'High': 1225.56,
#   'Low': 1212.47,
#   'Close': 1219.08,
#   'Adj Close': 1219.08,
#   'Volume': 245100.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 74,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 1222.27,
#   'High': 1229.29,
#   'Low': 1214.26,
#   'Close': 1228.05,
#   'Adj Close': 1228.05,
#   'Volume': 236700.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 75,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 1232.15,
#   'High': 1235.0,
#   'Low': 1220.1,
#   'Close': 1221.83,
#   'Adj Close': 1221.83,
#   'Volume': 206300.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 76,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 1234.0,
#   'High': 1235.92,
#   'Low': 1221.43,
#   'Close': 1225.22,
#   'Adj Close': 1225.22,
#   'Volume': 290100.0,
#   'Symbol': 'AZO',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 77,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 90.64,
#   'High': 91.28,
#   'Low': 90.36,
#   'Close': 91.26,
#   'Adj Close': 91.26,
#   'Volume': 1893630.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 78,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 89.58,
#   'High': 90.74,
#   'Low': 89.34,
#   'Close': 90.65,
#   'Adj Close': 90.65,
#   'Volume': 2452200.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 79,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 89.43,
#   'High': 89.49,
#   'Low': 88.43,
#   'Close': 89.37,
#   'Adj Close': 89.37,
#   'Volume': 2225700.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 80,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 88.21,
#   'High': 89.37,
#   'Low': 87.86,
#   'Close': 88.65,
#   'Adj Close': 88.65,
#   'Volume': 2047000.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 81,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 87.79,
#   'High': 89.21,
#   'Low': 87.46,
#   'Close': 88.41,
#   'Adj Close': 88.41,
#   'Volume': 2040900.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 82,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 86.47,
#   'High': 87.92,
#   'Low': 86.25,
#   'Close': 87.91,
#   'Adj Close': 87.91,
#   'Volume': 2270100.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 83,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 86.07,
#   'High': 87.64,
#   'Low': 85.91,
#   'Close': 87.18,
#   'Adj Close': 87.18,
#   'Volume': 1713600.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 84,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 88.39,
#   'High': 88.44,
#   'Low': 86.96,
#   'Close': 87.31,
#   'Adj Close': 87.31,
#   'Volume': 2447500.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 85,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 87.25,
#   'High': 88.18,
#   'Low': 86.95,
#   'Close': 87.8,
#   'Adj Close': 87.8,
#   'Volume': 1735200.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 86,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 87.09,
#   'High': 87.96,
#   'Low': 86.51,
#   'Close': 87.57,
#   'Adj Close': 87.57,
#   'Volume': 1520500.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 87,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 88.0,
#   'High': 88.13,
#   'Low': 86.95,
#   'Close': 87.01,
#   'Adj Close': 87.01,
#   'Volume': 1309600.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 88,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 87.99,
#   'High': 88.2,
#   'Low': 87.32,
#   'Close': 87.85,
#   'Adj Close': 87.85,
#   'Volume': 1342700.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 89,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 88.01,
#   'High': 88.51,
#   'Low': 87.43,
#   'Close': 87.93,
#   'Adj Close': 87.93,
#   'Volume': 741800.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 90,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 88.17,
#   'High': 88.32,
#   'Low': 87.25,
#   'Close': 87.64,
#   'Adj Close': 87.64,
#   'Volume': 1822200.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 91,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 89.21,
#   'High': 89.5,
#   'Low': 87.55,
#   'Close': 87.73,
#   'Adj Close': 87.73,
#   'Volume': 3650200.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 92,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 87.62,
#   'High': 88.84,
#   'Low': 87.05,
#   'Close': 88.64,
#   'Adj Close': 88.64,
#   'Volume': 3244900.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 93,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 86.68,
#   'High': 87.76,
#   'Low': 86.51,
#   'Close': 87.01,
#   'Adj Close': 87.01,
#   'Volume': 3172700.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 94,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 85.75,
#   'High': 86.48,
#   'Low': 84.55,
#   'Close': 86.36,
#   'Adj Close': 86.36,
#   'Volume': 1967000.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 95,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 85.08,
#   'High': 86.86,
#   'Low': 85.01,
#   'Close': 85.79,
#   'Adj Close': 85.79,
#   'Volume': 3643200.0,
#   'Symbol': 'BBY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 96,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 2090.25,
#   'High': 2090.25,
#   'Low': 2073.01,
#   'Close': 2080.5,
#   'Adj Close': 2080.5,
#   'Volume': 209350.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 97,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 2088.37,
#   'High': 2094.0,
#   'Low': 2076.94,
#   'Close': 2086.9,
#   'Adj Close': 2086.9,
#   'Volume': 198500.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 98,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 2072.0,
#   'High': 2090.0,
#   'Low': 2072.0,
#   'Close': 2084.29,
#   'Adj Close': 2084.29,
#   'Volume': 273800.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 99,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 2066.84,
#   'High': 2088.66,
#   'Low': 2057.14,
#   'Close': 2062.9,
#   'Adj Close': 2062.9,
#   'Volume': 325800.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 100,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 2047.39,
#   'High': 2072.83,
#   'Low': 2038.54,
#   'Close': 2068.05,
#   'Adj Close': 2068.05,
#   'Volume': 345300.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 101,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 2050.0,
#   'High': 2059.79,
#   'Low': 2035.0,
#   'Close': 2047.4,
#   'Adj Close': 2047.4,
#   'Volume': 384000.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 102,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 2042.47,
#   'High': 2067.69,
#   'Low': 2035.0,
#   'Close': 2065.48,
#   'Adj Close': 2065.48,
#   'Volume': 294000.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 103,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 2068.4,
#   'High': 2077.41,
#   'Low': 2053.22,
#   'Close': 2074.58,
#   'Adj Close': 2074.58,
#   'Volume': 329000.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 104,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 2046.51,
#   'High': 2057.99,
#   'Low': 2039.97,
#   'Close': 2053.73,
#   'Adj Close': 2053.73,
#   'Volume': 226900.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 105,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 2071.99,
#   'High': 2082.67,
#   'Low': 2050.47,
#   'Close': 2053.87,
#   'Adj Close': 2053.87,
#   'Volume': 224700.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 106,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 2063.0,
#   'High': 2080.99,
#   'Low': 2053.65,
#   'Close': 2072.54,
#   'Adj Close': 2072.54,
#   'Volume': 280000.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 107,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 2049.34,
#   'High': 2068.81,
#   'Low': 2047.65,
#   'Close': 2064.32,
#   'Adj Close': 2064.32,
#   'Volume': 182600.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 108,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 2032.24,
#   'High': 2047.3,
#   'Low': 2031.29,
#   'Close': 2044.0,
#   'Adj Close': 2044.0,
#   'Volume': 97300.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 109,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 2026.01,
#   'High': 2041.5,
#   'Low': 2017.68,
#   'Close': 2032.1,
#   'Adj Close': 2032.1,
#   'Volume': 219600.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 110,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 2017.0,
#   'High': 2025.0,
#   'Low': 2002.34,
#   'Close': 2023.26,
#   'Adj Close': 2023.26,
#   'Volume': 583200.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 111,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 1996.0,
#   'High': 2014.97,
#   'Low': 1994.76,
#   'Close': 2003.12,
#   'Adj Close': 2003.12,
#   'Volume': 277500.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 112,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 2008.67,
#   'High': 2008.67,
#   'Low': 1977.77,
#   'Close': 1991.51,
#   'Adj Close': 1991.51,
#   'Volume': 379800.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 113,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 2000.0,
#   'High': 2011.64,
#   'Low': 1991.0,
#   'Close': 2001.87,
#   'Adj Close': 2001.87,
#   'Volume': 311300.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 114,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 1983.47,
#   'High': 1998.01,
#   'Low': 1983.47,
#   'Close': 1995.02,
#   'Adj Close': 1995.02,
#   'Volume': 264100.0,
#   'Symbol': 'BKNG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 115,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 41.3,
#   'High': 41.49,
#   'Low': 41.06,
#   'Close': 41.38,
#   'Adj Close': 41.38,
#   'Volume': 1271303.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 116,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 41.84,
#   'High': 41.95,
#   'Low': 41.3,
#   'Close': 41.42,
#   'Adj Close': 41.42,
#   'Volume': 827100.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 117,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 42.92,
#   'High': 42.93,
#   'Low': 41.92,
#   'Close': 41.93,
#   'Adj Close': 41.93,
#   'Volume': 1190900.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 118,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 42.48,
#   'High': 43.0,
#   'Low': 42.09,
#   'Close': 42.7,
#   'Adj Close': 42.7,
#   'Volume': 1072000.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 119,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 42.1,
#   'High': 42.71,
#   'Low': 41.92,
#   'Close': 42.44,
#   'Adj Close': 42.44,
#   'Volume': 1383300.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 120,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 42.0,
#   'High': 42.29,
#   'Low': 41.61,
#   'Close': 42.18,
#   'Adj Close': 42.18,
#   'Volume': 846500.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 121,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 42.99,
#   'High': 43.35,
#   'Low': 42.22,
#   'Close': 42.36,
#   'Adj Close': 42.36,
#   'Volume': 1050700.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 122,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 44.0,
#   'High': 44.05,
#   'Low': 43.35,
#   'Close': 43.95,
#   'Adj Close': 43.95,
#   'Volume': 1189300.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 123,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 43.34,
#   'High': 43.75,
#   'Low': 43.27,
#   'Close': 43.38,
#   'Adj Close': 43.38,
#   'Volume': 662000.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 124,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 43.77,
#   'High': 43.89,
#   'Low': 43.31,
#   'Close': 43.4,
#   'Adj Close': 43.4,
#   'Volume': 600400.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 125,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 43.93,
#   'High': 44.14,
#   'Low': 43.59,
#   'Close': 43.76,
#   'Adj Close': 43.76,
#   'Volume': 665800.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 126,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 44.01,
#   'High': 44.07,
#   'Low': 43.39,
#   'Close': 43.81,
#   'Adj Close': 43.81,
#   'Volume': 599200.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 127,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 44.3,
#   'High': 44.3,
#   'Low': 43.69,
#   'Close': 43.88,
#   'Adj Close': 43.88,
#   'Volume': 331500.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 128,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 44.28,
#   'High': 44.45,
#   'Low': 43.78,
#   'Close': 44.3,
#   'Adj Close': 44.3,
#   'Volume': 876600.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 129,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 45.0,
#   'High': 45.07,
#   'Low': 44.08,
#   'Close': 44.22,
#   'Adj Close': 44.22,
#   'Volume': 2069200.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 130,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 45.06,
#   'High': 45.29,
#   'Low': 44.72,
#   'Close': 44.9,
#   'Adj Close': 44.9,
#   'Volume': 1071200.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 131,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 44.65,
#   'High': 45.35,
#   'Low': 44.44,
#   'Close': 45.2,
#   'Adj Close': 45.2,
#   'Volume': 1609500.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 132,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 44.4,
#   'High': 44.75,
#   'Low': 44.25,
#   'Close': 44.63,
#   'Adj Close': 44.63,
#   'Volume': 1043000.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 133,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 44.14,
#   'High': 44.67,
#   'Low': 44.0,
#   'Close': 44.14,
#   'Adj Close': 44.14,
#   'Volume': 1976400.0,
#   'Symbol': 'BWA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 134,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 49.1,
#   'High': 49.65,
#   'Low': 48.82,
#   'Close': 49.36,
#   'Adj Close': 49.36,
#   'Volume': 3685502.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 135,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 49.26,
#   'High': 49.58,
#   'Low': 48.8,
#   'Close': 48.85,
#   'Adj Close': 48.85,
#   'Volume': 4362500.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 136,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 49.14,
#   'High': 49.29,
#   'Low': 48.93,
#   'Close': 49.2,
#   'Adj Close': 49.2,
#   'Volume': 2588900.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 137,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 48.5,
#   'High': 49.03,
#   'Low': 48.43,
#   'Close': 48.76,
#   'Adj Close': 48.76,
#   'Volume': 5021400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 138,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 48.14,
#   'High': 48.67,
#   'Low': 48.13,
#   'Close': 48.53,
#   'Adj Close': 48.53,
#   'Volume': 5725400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 139,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 49.35,
#   'High': 49.4,
#   'Low': 48.27,
#   'Close': 48.38,
#   'Adj Close': 48.38,
#   'Volume': 6696400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 140,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 50.05,
#   'High': 50.4,
#   'Low': 49.57,
#   'Close': 49.89,
#   'Adj Close': 49.89,
#   'Volume': 4892300.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 141,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 51.35,
#   'High': 51.67,
#   'Low': 50.73,
#   'Close': 51.31,
#   'Adj Close': 51.31,
#   'Volume': 4201000.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 142,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 51.03,
#   'High': 51.13,
#   'Low': 50.75,
#   'Close': 50.83,
#   'Adj Close': 50.83,
#   'Volume': 3131000.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 143,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 51.64,
#   'High': 51.69,
#   'Low': 50.94,
#   'Close': 51.02,
#   'Adj Close': 51.02,
#   'Volume': 2568500.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 144,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 51.62,
#   'High': 51.74,
#   'Low': 51.19,
#   'Close': 51.33,
#   'Adj Close': 51.33,
#   'Volume': 2093400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 145,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 51.0,
#   'High': 51.45,
#   'Low': 50.76,
#   'Close': 51.33,
#   'Adj Close': 51.33,
#   'Volume': 3217100.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 146,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 51.4,
#   'High': 51.62,
#   'Low': 50.74,
#   'Close': 50.94,
#   'Adj Close': 50.94,
#   'Volume': 2142300.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 147,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 50.32,
#   'High': 51.27,
#   'Low': 50.15,
#   'Close': 51.26,
#   'Adj Close': 51.26,
#   'Volume': 5965400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 148,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 48.9,
#   'High': 51.21,
#   'Low': 48.26,
#   'Close': 50.21,
#   'Adj Close': 50.21,
#   'Volume': 15867400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 149,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 46.69,
#   'High': 47.03,
#   'Low': 46.57,
#   'Close': 46.65,
#   'Adj Close': 46.65,
#   'Volume': 4477400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 150,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 46.95,
#   'High': 47.16,
#   'Low': 46.57,
#   'Close': 46.58,
#   'Adj Close': 46.58,
#   'Volume': 6584400.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 151,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 46.76,
#   'High': 47.31,
#   'Low': 46.54,
#   'Close': 47.2,
#   'Adj Close': 47.2,
#   'Volume': 3246200.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 152,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 48.06,
#   'High': 48.06,
#   'Low': 46.86,
#   'Close': 46.99,
#   'Adj Close': 46.99,
#   'Volume': 4590100.0,
#   'Symbol': 'CCL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 153,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 506.04,
#   'High': 512.65,
#   'Low': 504.93,
#   'Close': 510.15,
#   'Adj Close': 510.15,
#   'Volume': 831554.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 154,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 507.79,
#   'High': 509.03,
#   'Low': 503.52,
#   'Close': 505.03,
#   'Adj Close': 505.03,
#   'Volume': 912700.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 155,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 501.5,
#   'High': 508.86,
#   'Low': 501.5,
#   'Close': 507.28,
#   'Adj Close': 507.28,
#   'Volume': 924300.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 156,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 499.0,
#   'High': 509.99,
#   'Low': 498.55,
#   'Close': 500.77,
#   'Adj Close': 500.77,
#   'Volume': 1063200.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 157,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 497.13,
#   'High': 500.65,
#   'Low': 495.55,
#   'Close': 499.16,
#   'Adj Close': 499.16,
#   'Volume': 1050800.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 158,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 492.66,
#   'High': 498.15,
#   'Low': 490.93,
#   'Close': 497.45,
#   'Adj Close': 497.45,
#   'Volume': 829900.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 159,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 485.53,
#   'High': 496.59,
#   'Low': 485.53,
#   'Close': 494.47,
#   'Adj Close': 494.47,
#   'Volume': 974100.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 160,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 487.41,
#   'High': 491.41,
#   'Low': 480.49,
#   'Close': 490.43,
#   'Adj Close': 490.43,
#   'Volume': 1378800.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 161,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 482.3,
#   'High': 487.08,
#   'Low': 481.97,
#   'Close': 485.08,
#   'Adj Close': 485.08,
#   'Volume': 757100.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 162,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 483.74,
#   'High': 484.93,
#   'Low': 478.39,
#   'Close': 483.08,
#   'Adj Close': 483.08,
#   'Volume': 702500.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 163,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 487.52,
#   'High': 487.52,
#   'Low': 481.89,
#   'Close': 483.69,
#   'Adj Close': 483.69,
#   'Volume': 507500.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 164,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 480.95,
#   'High': 487.18,
#   'Low': 480.95,
#   'Close': 485.73,
#   'Adj Close': 485.73,
#   'Volume': 752900.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 165,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 482.22,
#   'High': 482.94,
#   'Low': 480.26,
#   'Close': 480.86,
#   'Adj Close': 480.86,
#   'Volume': 463700.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 166,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 476.72,
#   'High': 483.08,
#   'Low': 475.46,
#   'Close': 480.72,
#   'Adj Close': 480.72,
#   'Volume': 1225600.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 167,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 479.96,
#   'High': 480.85,
#   'Low': 473.49,
#   'Close': 476.22,
#   'Adj Close': 476.22,
#   'Volume': 2831200.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 168,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 466.52,
#   'High': 475.89,
#   'Low': 466.2,
#   'Close': 475.67,
#   'Adj Close': 475.67,
#   'Volume': 1063200.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 169,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 472.64,
#   'High': 476.18,
#   'Low': 466.14,
#   'Close': 466.52,
#   'Adj Close': 466.52,
#   'Volume': 1081200.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 170,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 471.03,
#   'High': 476.26,
#   'Low': 469.23,
#   'Close': 471.13,
#   'Adj Close': 471.13,
#   'Volume': 1494300.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 171,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 477.87,
#   'High': 478.83,
#   'Low': 468.06,
#   'Close': 470.23,
#   'Adj Close': 470.23,
#   'Volume': 1341000.0,
#   'Symbol': 'CHTR',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 172,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 44.92,
#   'High': 45.87,
#   'Low': 44.9,
#   'Close': 45.8,
#   'Adj Close': 45.8,
#   'Volume': 15701177.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 173,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 45.63,
#   'High': 45.63,
#   'Low': 44.93,
#   'Close': 44.98,
#   'Adj Close': 44.98,
#   'Volume': 15896200.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 174,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 45.39,
#   'High': 45.61,
#   'Low': 45.18,
#   'Close': 45.51,
#   'Adj Close': 45.51,
#   'Volume': 14195400.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 175,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 44.94,
#   'High': 45.57,
#   'Low': 44.76,
#   'Close': 45.39,
#   'Adj Close': 45.39,
#   'Volume': 18097400.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 176,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 44.25,
#   'High': 45.01,
#   'Low': 44.22,
#   'Close': 44.93,
#   'Adj Close': 44.93,
#   'Volume': 24563700.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 177,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 44.66,
#   'High': 44.87,
#   'Low': 44.55,
#   'Close': 44.67,
#   'Adj Close': 44.46,
#   'Volume': 17628200.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 178,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 44.83,
#   'High': 45.22,
#   'Low': 44.57,
#   'Close': 45.01,
#   'Adj Close': 44.8,
#   'Volume': 20496400.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 179,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 45.36,
#   'High': 45.4,
#   'Low': 44.93,
#   'Close': 45.37,
#   'Adj Close': 45.16,
#   'Volume': 20170500.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 180,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 45.12,
#   'High': 45.18,
#   'Low': 44.77,
#   'Close': 44.97,
#   'Adj Close': 44.76,
#   'Volume': 13881700.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 181,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 45.1,
#   'High': 45.34,
#   'Low': 44.94,
#   'Close': 45.18,
#   'Adj Close': 44.97,
#   'Volume': 12896900.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 182,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 45.1,
#   'High': 45.22,
#   'Low': 44.86,
#   'Close': 45.1,
#   'Adj Close': 44.89,
#   'Volume': 12272100.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 183,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 44.73,
#   'High': 45.0,
#   'Low': 44.57,
#   'Close': 44.97,
#   'Adj Close': 44.76,
#   'Volume': 12019600.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 184,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 44.1,
#   'High': 44.7,
#   'Low': 44.1,
#   'Close': 44.53,
#   'Adj Close': 44.32,
#   'Volume': 6504700.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 185,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 44.08,
#   'High': 44.25,
#   'Low': 43.95,
#   'Close': 44.1,
#   'Adj Close': 43.89,
#   'Volume': 22609300.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 186,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 43.74,
#   'High': 44.19,
#   'Low': 43.23,
#   'Close': 44.09,
#   'Adj Close': 43.88,
#   'Volume': 41414500.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 187,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 43.27,
#   'High': 43.65,
#   'Low': 43.03,
#   'Close': 43.64,
#   'Adj Close': 43.43,
#   'Volume': 20723200.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 188,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 43.45,
#   'High': 43.88,
#   'Low': 43.14,
#   'Close': 43.19,
#   'Adj Close': 42.99,
#   'Volume': 27054900.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 189,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 43.89,
#   'High': 43.89,
#   'Low': 43.27,
#   'Close': 43.39,
#   'Adj Close': 43.19,
#   'Volume': 18742500.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 190,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 43.89,
#   'High': 44.08,
#   'Low': 43.32,
#   'Close': 43.53,
#   'Adj Close': 43.33,
#   'Volume': 23558800.0,
#   'Symbol': 'CMCSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 191,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 856.13,
#   'High': 869.77,
#   'Low': 851.41,
#   'Close': 863.0,
#   'Adj Close': 863.0,
#   'Volume': 297329.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 192,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 866.0,
#   'High': 866.57,
#   'Low': 853.09,
#   'Close': 857.77,
#   'Adj Close': 857.77,
#   'Volume': 301900.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 193,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 866.86,
#   'High': 877.0,
#   'Low': 859.47,
#   'Close': 862.67,
#   'Adj Close': 862.67,
#   'Volume': 457300.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 194,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 856.15,
#   'High': 867.0,
#   'Low': 856.15,
#   'Close': 856.73,
#   'Adj Close': 856.73,
#   'Volume': 262500.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 195,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 863.0,
#   'High': 863.0,
#   'Low': 854.39,
#   'Close': 860.08,
#   'Adj Close': 860.08,
#   'Volume': 243300.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 196,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 862.0,
#   'High': 862.8,
#   'Low': 854.0,
#   'Close': 858.02,
#   'Adj Close': 858.02,
#   'Volume': 405200.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 197,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 853.24,
#   'High': 870.94,
#   'Low': 853.24,
#   'Close': 865.13,
#   'Adj Close': 865.13,
#   'Volume': 422700.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 198,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 839.97,
#   'High': 859.19,
#   'Low': 837.53,
#   'Close': 858.19,
#   'Adj Close': 858.19,
#   'Volume': 487300.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 199,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 837.24,
#   'High': 842.27,
#   'Low': 833.36,
#   'Close': 837.11,
#   'Adj Close': 837.11,
#   'Volume': 282200.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 200,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 838.17,
#   'High': 838.75,
#   'Low': 829.01,
#   'Close': 836.07,
#   'Adj Close': 836.07,
#   'Volume': 211400.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 201,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 839.97,
#   'High': 840.0,
#   'Low': 835.0,
#   'Close': 836.79,
#   'Adj Close': 836.79,
#   'Volume': 201900.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 202,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 829.41,
#   'High': 839.28,
#   'Low': 828.24,
#   'Close': 838.6,
#   'Adj Close': 838.6,
#   'Volume': 255400.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 203,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 827.1,
#   'High': 829.41,
#   'Low': 823.16,
#   'Close': 828.89,
#   'Adj Close': 828.89,
#   'Volume': 91900.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 204,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 837.83,
#   'High': 838.25,
#   'Low': 827.93,
#   'Close': 828.29,
#   'Adj Close': 828.29,
#   'Volume': 294400.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 205,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 838.0,
#   'High': 838.82,
#   'Low': 831.77,
#   'Close': 834.53,
#   'Adj Close': 834.53,
#   'Volume': 363000.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 206,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 825.0,
#   'High': 836.03,
#   'Low': 825.0,
#   'Close': 833.92,
#   'Adj Close': 833.92,
#   'Volume': 316000.0,
#   'Symbol': 'CMG',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 207,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 832.27,
#   'High': 839.13,
#   'Low': 825.86,
#   'Close': 826.88,
#   'Adj Close': 826.88,
#   'Volume': 423200.0,
#   'Symbol': 'CMG',
# ...
#   'Open': 19.3,
#   'High': 19.39,
#   'Low': 18.38,
#   'Close': 18.41,
#   'Adj Close': 18.41,
#   'Volume': 4693000.0,
#   'Symbol': 'NWL',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 932,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 14.71,
#   'High': 14.92,
#   'Low': 14.67,
#   'Close': 14.9,
#   'Adj Close': 14.9,
#   'Volume': 330456.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 933,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 14.85,
#   'High': 14.85,
#   'Low': 14.69,
#   'Close': 14.72,
#   'Adj Close': 14.72,
#   'Volume': 437000.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 934,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 15.0,
#   'High': 15.05,
#   'Low': 14.26,
#   'Close': 14.81,
#   'Adj Close': 14.81,
#   'Volume': 661900.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 935,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 14.93,
#   'High': 15.11,
#   'Low': 14.93,
#   'Close': 14.97,
#   'Adj Close': 14.97,
#   'Volume': 528100.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 936,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 14.72,
#   'High': 14.99,
#   'Low': 14.7,
#   'Close': 14.93,
#   'Adj Close': 14.93,
#   'Volume': 467700.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 937,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 14.79,
#   'High': 14.79,
#   'Low': 14.62,
#   'Close': 14.77,
#   'Adj Close': 14.77,
#   'Volume': 475100.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 938,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 14.61,
#   'High': 14.86,
#   'Low': 14.61,
#   'Close': 14.82,
#   'Adj Close': 14.82,
#   'Volume': 1037300.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 939,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 14.63,
#   'High': 14.82,
#   'Low': 14.55,
#   'Close': 14.81,
#   'Adj Close': 14.81,
#   'Volume': 775400.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 940,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 14.48,
#   'High': 14.51,
#   'Low': 14.33,
#   'Close': 14.51,
#   'Adj Close': 14.51,
#   'Volume': 327700.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 941,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 14.42,
#   'High': 14.5,
#   'Low': 14.41,
#   'Close': 14.46,
#   'Adj Close': 14.46,
#   'Volume': 344800.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 942,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 14.6,
#   'High': 14.6,
#   'Low': 14.46,
#   'Close': 14.47,
#   'Adj Close': 14.47,
#   'Volume': 408700.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 943,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 14.36,
#   'High': 14.54,
#   'Low': 14.34,
#   'Close': 14.53,
#   'Adj Close': 14.53,
#   'Volume': 749300.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 944,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 14.28,
#   'High': 14.34,
#   'Low': 14.27,
#   'Close': 14.29,
#   'Adj Close': 14.29,
#   'Volume': 112200.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 945,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 14.26,
#   'High': 14.36,
#   'Low': 14.25,
#   'Close': 14.31,
#   'Adj Close': 14.31,
#   'Volume': 404200.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 946,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 14.61,
#   'High': 14.61,
#   'Low': 14.14,
#   'Close': 14.31,
#   'Adj Close': 14.31,
#   'Volume': 1771100.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 947,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 14.35,
#   'High': 14.41,
#   'Low': 14.22,
#   'Close': 14.31,
#   'Adj Close': 14.31,
#   'Volume': 629700.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 948,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 14.23,
#   'High': 14.46,
#   'Low': 14.13,
#   'Close': 14.38,
#   'Adj Close': 14.38,
#   'Volume': 672300.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 949,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 14.17,
#   'High': 14.22,
#   'Low': 14.01,
#   'Close': 14.16,
#   'Adj Close': 14.16,
#   'Volume': 583600.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 950,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 14.0,
#   'High': 14.26,
#   'Low': 14.0,
#   'Close': 14.09,
#   'Adj Close': 14.09,
#   'Volume': 683200.0,
#   'Symbol': 'NWS',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 951,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 14.38,
#   'High': 14.58,
#   'Low': 14.3,
#   'Close': 14.57,
#   'Adj Close': 14.57,
#   'Volume': 1647549.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 952,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 14.41,
#   'High': 14.47,
#   'Low': 14.32,
#   'Close': 14.35,
#   'Adj Close': 14.35,
#   'Volume': 1862500.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 953,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 14.54,
#   'High': 14.59,
#   'Low': 14.32,
#   'Close': 14.43,
#   'Adj Close': 14.43,
#   'Volume': 1846900.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 954,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 14.47,
#   'High': 14.68,
#   'Low': 14.47,
#   'Close': 14.54,
#   'Adj Close': 14.54,
#   'Volume': 1695900.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 955,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 14.38,
#   'High': 14.59,
#   'Low': 14.29,
#   'Close': 14.5,
#   'Adj Close': 14.5,
#   'Volume': 1585000.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 956,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 14.34,
#   'High': 14.37,
#   'Low': 14.2,
#   'Close': 14.36,
#   'Adj Close': 14.36,
#   'Volume': 2011900.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 957,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 14.22,
#   'High': 14.43,
#   'Low': 14.22,
#   'Close': 14.4,
#   'Adj Close': 14.4,
#   'Volume': 1976500.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 958,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 14.17,
#   'High': 14.45,
#   'Low': 14.16,
#   'Close': 14.44,
#   'Adj Close': 14.44,
#   'Volume': 2182900.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 959,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 14.1,
#   'High': 14.14,
#   'Low': 13.95,
#   'Close': 14.14,
#   'Adj Close': 14.14,
#   'Volume': 1456700.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 960,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 14.13,
#   'High': 14.16,
#   'Low': 14.06,
#   'Close': 14.07,
#   'Adj Close': 14.07,
#   'Volume': 1436800.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 961,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 14.13,
#   'High': 14.23,
#   'Low': 14.07,
#   'Close': 14.15,
#   'Adj Close': 14.15,
#   'Volume': 1020700.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 962,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 14.05,
#   'High': 14.18,
#   'Low': 14.03,
#   'Close': 14.17,
#   'Adj Close': 14.17,
#   'Volume': 979600.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 963,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 13.98,
#   'High': 14.03,
#   'Low': 13.92,
#   'Close': 13.98,
#   'Adj Close': 13.98,
#   'Volume': 769000.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 964,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 14.27,
#   'High': 14.27,
#   'Low': 13.89,
#   'Close': 14.0,
#   'Adj Close': 14.0,
#   'Volume': 1111000.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 965,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 14.05,
#   'High': 14.08,
#   'Low': 13.76,
#   'Close': 13.95,
#   'Adj Close': 13.95,
#   'Volume': 5927800.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 966,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 14.01,
#   'High': 14.05,
#   'Low': 13.82,
#   'Close': 13.92,
#   'Adj Close': 13.92,
#   'Volume': 3206900.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 967,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 13.78,
#   'High': 14.07,
#   'Low': 13.75,
#   'Close': 14.06,
#   'Adj Close': 14.06,
#   'Volume': 2697800.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 968,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 13.78,
#   'High': 13.84,
#   'Low': 13.62,
#   'Close': 13.79,
#   'Adj Close': 13.79,
#   'Volume': 1604600.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 969,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 13.66,
#   'High': 13.94,
#   'Low': 13.66,
#   'Close': 13.73,
#   'Adj Close': 13.73,
#   'Volume': 2146000.0,
#   'Symbol': 'NWSA',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 970,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 79.27,
#   'High': 79.68,
#   'Low': 78.81,
#   'Close': 79.68,
#   'Adj Close': 79.68,
#   'Volume': 1493028.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 971,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 79.75,
#   'High': 80.09,
#   'Low': 79.18,
#   'Close': 79.25,
#   'Adj Close': 79.25,
#   'Volume': 1278600.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 972,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 79.5,
#   'High': 80.02,
#   'Low': 79.39,
#   'Close': 79.75,
#   'Adj Close': 79.75,
#   'Volume': 1838700.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 973,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 79.35,
#   'High': 79.95,
#   'Low': 79.25,
#   'Close': 79.32,
#   'Adj Close': 79.32,
#   'Volume': 1737400.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 974,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 79.8,
#   'High': 80.04,
#   'Low': 78.97,
#   'Close': 79.11,
#   'Adj Close': 79.11,
#   'Volume': 1598300.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 975,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 79.39,
#   'High': 79.67,
#   'Low': 78.96,
#   'Close': 79.53,
#   'Adj Close': 79.53,
#   'Volume': 1436600.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 976,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 79.0,
#   'High': 80.01,
#   'Low': 78.88,
#   'Close': 79.93,
#   'Adj Close': 79.93,
#   'Volume': 1018300.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 977,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 81.15,
#   'High': 81.17,
#   'Low': 78.96,
#   'Close': 79.87,
#   'Adj Close': 79.87,
#   'Volume': 1951400.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 978,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 80.66,
#   'High': 81.02,
#   'Low': 80.5,
#   'Close': 81.02,
#   'Adj Close': 81.02,
#   'Volume': 1148700.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 979,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 81.23,
#   'High': 81.31,
#   'Low': 80.71,
#   'Close': 80.91,
#   'Adj Close': 80.91,
#   'Volume': 767100.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 980,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 81.2,
#   'High': 81.34,
#   'Low': 80.79,
#   'Close': 80.84,
#   'Adj Close': 80.84,
#   'Volume': 674300.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 981,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 80.78,
#   'High': 81.01,
#   'Low': 80.63,
#   'Close': 80.9,
#   'Adj Close': 80.9,
#   'Volume': 665100.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 982,
#   'Date': Timestamp('2019-12-24 00:00:00'),
#   'Open': 80.83,
#   'High': 81.1,
#   'Low': 80.52,
#   'Close': 80.84,
#   'Adj Close': 80.84,
#   'Volume': 325100.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 983,
#   'Date': Timestamp('2019-12-23 00:00:00'),
#   'Open': 80.86,
#   'High': 81.06,
#   'Low': 80.35,
#   'Close': 80.71,
#   'Adj Close': 80.71,
#   'Volume': 1108700.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 984,
#   'Date': Timestamp('2019-12-20 00:00:00'),
#   'Open': 80.11,
#   'High': 81.47,
#   'Low': 79.89,
#   'Close': 80.83,
#   'Adj Close': 80.83,
#   'Volume': 2851100.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 985,
#   'Date': Timestamp('2019-12-19 00:00:00'),
#   'Open': 79.44,
#   'High': 79.76,
#   'Low': 79.2,
#   'Close': 79.61,
#   'Adj Close': 79.61,
#   'Volume': 1834700.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 986,
#   'Date': Timestamp('2019-12-18 00:00:00'),
#   'Open': 81.0,
#   'High': 81.19,
#   'Low': 79.84,
#   'Close': 79.88,
#   'Adj Close': 79.23,
#   'Volume': 1800100.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 987,
#   'Date': Timestamp('2019-12-17 00:00:00'),
#   'Open': 81.4,
#   'High': 81.54,
#   'Low': 80.76,
#   'Close': 81.01,
#   'Adj Close': 80.35,
#   'Volume': 1682700.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 988,
#   'Date': Timestamp('2019-12-16 00:00:00'),
#   'Open': 82.44,
#   'High': 82.69,
#   'Low': 81.11,
#   'Close': 81.77,
#   'Adj Close': 81.1,
#   'Volume': 1460900.0,
#   'Symbol': 'OMC',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 989,
#   'Date': Timestamp('2020-01-13 00:00:00'),
#   'Open': 436.63,
#   'High': 437.84,
#   'Low': 433.07,
#   'Close': 435.5,
#   'Adj Close': 435.5,
#   'Volume': 545569.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 990,
#   'Date': Timestamp('2020-01-10 00:00:00'),
#   'Open': 437.88,
#   'High': 438.39,
#   'Low': 434.9,
#   'Close': 436.85,
#   'Adj Close': 436.85,
#   'Volume': 569400.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 991,
#   'Date': Timestamp('2020-01-09 00:00:00'),
#   'Open': 434.99,
#   'High': 439.54,
#   'Low': 433.45,
#   'Close': 437.37,
#   'Adj Close': 437.37,
#   'Volume': 561200.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 992,
#   'Date': Timestamp('2020-01-08 00:00:00'),
#   'Open': 428.87,
#   'High': 437.57,
#   'Low': 428.87,
#   'Close': 431.9,
#   'Adj Close': 431.9,
#   'Volume': 479500.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 993,
#   'Date': Timestamp('2020-01-07 00:00:00'),
#   'Open': 433.94,
#   'High': 434.51,
#   'Low': 425.28,
#   'Close': 428.77,
#   'Adj Close': 428.77,
#   'Volume': 661500.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 994,
#   'Date': Timestamp('2020-01-06 00:00:00'),
#   'Open': 437.03,
#   'High': 437.03,
#   'Low': 429.22,
#   'Close': 434.66,
#   'Adj Close': 434.66,
#   'Volume': 837100.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 995,
#   'Date': Timestamp('2020-01-03 00:00:00'),
#   'Open': 435.81,
#   'High': 439.22,
#   'Low': 433.04,
#   'Close': 438.75,
#   'Adj Close': 438.75,
#   'Volume': 482900.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 996,
#   'Date': Timestamp('2020-01-02 00:00:00'),
#   'Open': 438.5,
#   'High': 439.06,
#   'Low': 434.44,
#   'Close': 437.52,
#   'Adj Close': 437.52,
#   'Volume': 796100.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 997,
#   'Date': Timestamp('2019-12-31 00:00:00'),
#   'Open': 437.76,
#   'High': 440.17,
#   'Low': 435.97,
#   'Close': 438.26,
#   'Adj Close': 438.26,
#   'Volume': 390500.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 998,
#   'Date': Timestamp('2019-12-30 00:00:00'),
#   'Open': 437.36,
#   'High': 439.26,
#   'Low': 435.43,
#   'Close': 437.51,
#   'Adj Close': 437.51,
#   'Volume': 297800.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 999,
#   'Date': Timestamp('2019-12-27 00:00:00'),
#   'Open': 439.65,
#   'High': 441.0,
#   'Low': 436.05,
#   'Close': 437.21,
#   'Adj Close': 437.21,
#   'Volume': 256700.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  {'_id': 1000,
#   'Date': Timestamp('2019-12-26 00:00:00'),
#   'Open': 440.72,
#   'High': 442.04,
#   'Low': 436.53,
#   'Close': 439.09,
#   'Adj Close': 439.09,
#   'Volume': 242200.0,
#   'Symbol': 'ORLY',
#   'Sector': 'Consumer Discretionary'},
#  ...]

# %%
# Set up the MongoDB connection through pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# Create DB

db = myclient["stock_Data"]

# Create collection and insert all the data into the MongoDB

mycol = db["Market_Data"]
mycol.drop()
mycol.insert_many(market_data)

# %% [markdown]
# # Func to return 1 company stock data - Download historical market data ( 1mo) from Yahoo! Finance

# %%
def stock_data():
    stock1 = yf.Ticker("GOOGL")
    stock_data1=stock.history(period="1mo",actions=False,auto_adjust=False)
    # map  ticker symbol to sector and add as columns to dataframe
    stock_data1['Symbol']="GOOGL"
    stock_data1['Sector']=stock_data1['Symbol'].map(sector_map)
    stock_data1
    #  sort data by descending order on date and reset index
    stock_data1.reset_index(inplace=True)
    stock_data1.sort_values(by=['Date'], ascending=False,inplace=True)
    stock_data1.reset_index(drop=True,inplace=True)
    return stock_data1 # this returns a dataframe, let me know if this needs to be a dict.
# Out:
#          Date    Open    High     Low   Close  Adj Close   Volume Symbol  \
# 0  2020-01-13  136.07  136.75  135.46  136.51     136.51  1797600  GOOGL
# 1  2020-01-10  135.30  136.00  134.77  135.57     135.57  1249000  GOOGL
# 2  2020-01-09  134.01  136.37  134.01  135.06     135.06  2075400  GOOGL
# 3  2020-01-08  133.76  135.27  133.24  133.29     133.29  1766700  GOOGL
# 4  2020-01-07  133.00  134.81  132.67  133.58     133.58  1224500  GOOGL
# 5  2020-01-06  133.78  134.07  132.71  133.13     133.13  2334100  GOOGL
# 6  2020-01-03  132.48  134.91  132.27  134.16     134.16  1274000  GOOGL
# 7  2020-01-02  132.05  134.28  131.48  134.14     134.14  1576700  GOOGL
# 8  2019-12-31  132.01  132.58  131.45  132.35     132.35  1128600  GOOGL
# 9  2019-12-30  133.57  133.66  131.81  132.21     132.21   942000  GOOGL
# 10 2019-12-27  133.40  133.48  132.38  133.25     133.25  1296100  GOOGL
# 11 2019-12-26  133.19  133.19  132.32  133.03     133.03   929400  GOOGL
# 12 2019-12-24  132.21  133.08  131.29  132.92     132.92   442500  GOOGL
# 13 2019-12-23  132.71  133.06  131.39  132.37     132.37  1632300  GOOGL
# 14 2019-12-20  129.38  133.52  128.98  132.68     132.68  5320300  GOOGL
# 15 2019-12-19  127.63  128.89  127.45  128.74     128.74  2055700  GOOGL
# 16 2019-12-18  127.15  127.63  126.56  126.99     126.99  2754200  GOOGL
# 17 2019-12-17  126.72  127.36  125.24  127.10     127.10  1994800  GOOGL
# 18 2019-12-16  125.00  126.50  124.37  126.46     126.46  1391100  GOOGL
#
#                     Sector
# 0   Information Technology
# 1   Information Technology
# 2   Information Technology
# 3   Information Technology
# 4   Information Technology
# 5   Information Technology
# 6   Information Technology
# 7   Information Technology
# 8   Information Technology
# 9   Information Technology
# 10  Information Technology
# 11  Information Technology
# 12  Information Technology
# 13  Information Technology
# 14  Information Technology
# 15  Information Technology
# 16  Information Technology
# 17  Information Technology
# 18  Information Technology

# %%
# Get data function
def get_data(df):  
    data = stock_data1.copy()
    data['Date'] = data['Date'].str.split('-').str[2]
    data['Date'] = pd.to_numeric(data['date'])
    return [ data['Date'].tolist(), data['Adj Close'].tolist() ] # Convert Series to list
dates, prices = get_data(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb5fc2edb2a7> in <module>
#       5     data['Date'] = pd.to_numeric(data['date'])
#       6     return [ data['Date'].tolist(), data['Adj Close'].tolist() ] # Convert Series to list
# ----> 7 dates, prices = get_data(df)
#
# NameError: name 'df' is not defined
